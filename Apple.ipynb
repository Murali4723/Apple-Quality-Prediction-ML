# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('/content/apple_quality.xlsx')

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#     Acidity Quality
# 0  -0.49159    good
# 1 -0.722809    good
# 2  2.621636     bad
# 3  0.790723    good
# 4  0.501984    good

# %%
df = df.iloc[:-1]  # Removes the last row

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
# ...

# %%
df.isnull().sum()
# Out:
# A_id           0
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %% [markdown]
# Initial Observations:
#
# The dataset contains 4001 rows and 9 columns.
#
# There are no missing values in the columns A_id, Size, Weight, Sweetness,
# Crunchiness, Juiciness, Ripeness, and Quality.
#
# The target variable "Quality" is categorical with values like "good" and "bad".

# %%
df.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
q1=df.Size.quantile(0.25)
q3=df.Size.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Size']=[min if x<min else max if x>max else x for x in df['Size']]
# Out:
# <ipython-input-24-3477dfa0b7ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size']=[min if x<min else max if x>max else x for x in df['Size']]

# %%
q1=df.Weight.quantile(0.25)
q3=df.Weight.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Weight']=[min if x<min else max if x>max else x for x in df['Weight']]
# Out:
# <ipython-input-27-1be9f0e59057>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight']=[min if x<min else max if x>max else x for x in df['Weight']]

# %%
q1=df.Sweetness.quantile(0.25)
q3=df.Sweetness.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Sweetness']=[min if x<min else max if x>max else x for x in df['Sweetness']]
# Out:
# <ipython-input-30-0b5896e07cca>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sweetness']=[min if x<min else max if x>max else x for x in df['Sweetness']]

# %%
q1=df.Crunchiness.quantile(0.25)
q3=df.Crunchiness.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Crunchiness']=[min if x<min else max if x>max else x for x in df['Crunchiness']]
# Out:
# <ipython-input-33-e0741b6d3af4>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Crunchiness']=[min if x<min else max if x>max else x for x in df['Crunchiness']]

# %%
q1=df.Juiciness.quantile(0.25)
q3=df.Juiciness.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Juiciness']=[min if x<min else max if x>max else x for x in df['Juiciness']]
# Out:
# <ipython-input-36-6de53a02a956>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Juiciness']=[min if x<min else max if x>max else x for x in df['Juiciness']]

# %%
q1=df.Ripeness.quantile(0.25)
q3=df.Ripeness.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Ripeness']=[min if x<min else max if x>max else x for x in df['Ripeness']]
# Out:
# <ipython-input-39-46fb937c602b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ripeness']=[min if x<min else max if x>max else x for x in df['Ripeness']]

# %%
q1=df.Acidity.quantile(0.25)
q3=df.Acidity.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Acidity']=[min if x<min else max if x>max else x for x in df['Acidity']]
# Out:
# <ipython-input-42-3b6cd44c6d64>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Acidity']=[min if x<min else max if x>max else x for x in df['Acidity']]

# %%
# Create subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 12))
fig.suptitle("Feature Distributions")

sns.histplot(df["Size"], kde=True, ax=axes[0, 0])
axes[0, 0].set_title("Distribution of Size")

sns.histplot(df["Weight"], kde=True, ax=axes[0, 1])
axes[0, 1].set_title("Distribution of Weight")

sns.histplot(df["Sweetness"], kde=True, ax=axes[0, 2])
axes[0, 2].set_title("Distribution of Sweetness")

sns.histplot(df["Crunchiness"], kde=True, ax=axes[1, 0])
axes[1, 0].set_title("Distribution of Crunchiness")

sns.histplot(df["Juiciness"], kde=True, ax=axes[1, 1])
axes[1, 1].set_title("Distribution of Juiciness")

sns.histplot(df["Ripeness"], kde=True, ax=axes[1, 2])
axes[1, 2].set_title("Distribution of Ripeness")

sns.histplot(df["Acidity"], kde=True, ax=axes[2, 0])
axes[2, 0].set_title("Distribution of Acidity")

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# Key Insights from Descriptive Statistics:
#
#
# Size, Weight, Sweetness, Crunchiness, Juiciness, Ripeness, and Acidity all have varying distributions.
#
# Acidity ranges from -7.01 to 7.40, with a mean close to zero, suggesting a near-normal distribution.
#
# Juiciness and Sweetness have a wider spread, indicating potential outliers.
#
# Crunchiness ranges widely, with values from -6.05 to 7.61.
#
# The median values of most features are near zero, indicating balanced distributions.

# %%
# Correlation matrix for numeric features only
numeric_df = df.select_dtypes(include=np.number)
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap (Numeric Features)")
plt.show()

# %%
# Create subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 12))
fig.suptitle("Feature Distributions by Apple Quality")

sns.boxplot(data=df, x="Quality", y="Size", ax=axes[0, 0])
axes[0, 0].set_title("Size vs Quality")

sns.boxplot(data=df, x="Quality", y="Weight", ax=axes[0, 1])
axes[0, 1].set_title("Weight vs Quality")

sns.boxplot(data=df, x="Quality", y="Sweetness", ax=axes[0, 2])
axes[0, 2].set_title("Sweetness vs Quality")

sns.boxplot(data=df, x="Quality", y="Crunchiness", ax=axes[1, 0])
axes[1, 0].set_title("Crunchiness vs Quality")

sns.boxplot(data=df, x="Quality", y="Juiciness", ax=axes[1, 1])
axes[1, 1].set_title("Juiciness vs Quality")

sns.boxplot(data=df, x="Quality", y="Ripeness", ax=axes[1, 2])
axes[1, 2].set_title("Ripeness vs Quality")

sns.boxplot(data=df, x="Quality", y="Acidity", ax=axes[2, 0])
axes[2, 0].set_title("Acidity vs Quality")

plt.show()

# %% [markdown]
# Correlation Insights:
#
# Sweetness and Juiciness show a moderate positive correlation, indicating that sweeter apples might also be juicier.
#
# Crunchiness and Ripeness have a weak correlation, suggesting these traits are independent.
#
# Acidity has a weak correlation with other variables, indicating it might independently influence quality.
#
# The boxplots reveal clear differences in feature distributions based on Quality. For example:
#
# Good quality apples tend to have higher sweetness and juiciness.
#
# Lower acidity seems to be associated with good quality.
#
# Size and weight show some variations but aren't strong indicators alone.

# %%
df['Quality'].value_counts()
# Out:
# Quality
# good    2004
# bad     1996
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df["Quality"] = label_encoder.fit_transform(df["Quality"])
# Out:
# <ipython-input-58-34f9f60a6c1a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Quality"] = label_encoder.fit_transform(df["Quality"])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(["A_id", "Quality"],axis=1),df['Quality'],test_size=0.3,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((2800, 7), (1200, 7))

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
log_reg = LogisticRegression()
log_reg.fit(X_train_scaled, y_train)
y_pred = log_reg.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.7283
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       612
#            1       0.71      0.74      0.73       588
#
#     accuracy                           0.73      1200
#    macro avg       0.73      0.73      0.73      1200
# weighted avg       0.73      0.73      0.73      1200

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_test, y_pred)

conf_matrix_df = pd.DataFrame(conf_matrix,
                              index=["Actual Bad", "Actual Good"],
                              columns=["Predicted Bad", "Predicted Good"])

print(conf_matrix_df)
# Out:
#              Predicted Bad  Predicted Good
# Actual Bad             438             174
# Actual Good            152             436

# %% [markdown]
# ###Model Evaluation
# The model was evaluated on the test set using the following metrics:
#
# ## Accuracy Score
# The overall accuracy of the model was 72%, meaning the model correctly classified apple quality in a significant portion of test cases.
#
# ## Classification Report
# The classification report provides insights into precision, recall, and F1-score for each class:
#
#     Metric	Class 0 (Bad)	Class 1 (Good)
#     Precision	0.74	0.71
#     Recall	0.72	0.74
#     F1-Score	0.73	0.73
#     Support	612	588
# Precision: Indicates the proportion of correct predictions for each class.
#
# Recall: Measures the ability of the model to capture all relevant instances.
#
# F1-Score: Harmonic mean of precision and recall, providing a balance between the two.
#
# 4.3 Confusion Matrix
# The confusion matrix helps visualize true positives, false positives, true negatives, and false negatives in the predictions.
#
#             Predicted 0   Predicted 1
#     Actual 0     TP         FP
#     Actual 1     FN         TN
#
# Where:
#
# TP (True Positive): Correctly predicted good quality apples
#
# FP (False Positive): Incorrectly classified bad apples as good
#
# FN (False Negative): Incorrectly classified good apples as bad
#
# TN (True Negative): Correctly predicted bad quality apples
#
# ## Conclusion & Next Steps
# The Logistic Regression model performed well, achieving a high accuracy score.
#
# For better performance, we could explore more advanced models such as Random Forest.

# %% [markdown]
# ### Support Vector Classifier

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
svm_model = SVC(kernel="rbf", C=1.0, random_state=42)
svm_model.fit(X_train_scaled, y_train)

# Predict and evaluate
y_pred = svm_model.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

# Display results
print(f"Accuracy: {accuracy:.4f}")
print("\nClassification Report:\n", classification_rep)
print("\nConfusion Matrix:\n", pd.DataFrame(conf_matrix,
      index=["Actual Bad", "Actual Good"],
      columns=["Predicted Bad", "Predicted Good"]))
# Out:
# Accuracy: 0.8800
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88       612
#            1       0.86      0.90      0.88       588
#
#     accuracy                           0.88      1200
#    macro avg       0.88      0.88      0.88      1200
# weighted avg       0.88      0.88      0.88      1200
#
#
# Confusion Matrix:
#               Predicted Bad  Predicted Good
# Actual Bad             527              85
# Actual Good             59             529

# %% [markdown]
# ### Model Evaluation
# The model was evaluated on the test set using various metrics:
#
# ## Accuracy Score
# The model achieved an accuracy of 88%.
#
# This indicates the percentage of correctly classified apples in the test set.
#
# ## Classification Report
#     Metric	Class 0 (Bad)	Class 1 (Good)
#     Precision	        0.90	0.86
#     Recall	          0.86	0.90
#     F1-Score	        0.88	0.88
#     Support            612	588
#
#
# Precision: Measures how many of the predicted apples in each class were correct.
#
# Recall: Measures how many of the actual apples in each class were correctly classified.
#
# F1-Score: The harmonic mean of precision and recall, balancing both metrics.
#
# 4.3 Confusion Matrix
# The confusion matrix shows the breakdown of correct and incorrect classifications.
#
# markdown
# Copy
# Edit
#          Predicted 0   Predicted 1
#     Actual 0     527         85
#     Actual 1     59         529
# Where:
#
# TP (True Positive): Correctly predicted good quality apples
#
# FP (False Positive): Incorrectly classified bad apples as good
#
# FN (False Negative): Incorrectly classified good apples as bad
#
# TN (True Negative): Correctly predicted bad quality apples
#
# ## Conclusion & Next Steps
#
# The SVM model performed well, but its effectiveness depends on the dataset size and feature distribution.
#
# Other potential models such as Random Forest, XGBoost can be tested for better performance.

# %% [markdown]
# ### RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_scaled, y_train)

# Compute evaluation metrics
accuracy_rf = accuracy_score(y_test, y_pred)
classification_rep_rf = classification_report(y_test, y_pred, output_dict=True)
conf_matrix_rf = confusion_matrix(y_test, y_pred)

# Extract precision, recall, f1-score for both classes
precision_bad_rf = classification_rep_rf["0"]["precision"]
recall_bad_rf = classification_rep_rf["0"]["recall"]
f1_score_bad_rf = classification_rep_rf["0"]["f1-score"]
support_bad_rf = classification_rep_rf["0"]["support"]

precision_good_rf = classification_rep_rf["1"]["precision"]
recall_good_rf = classification_rep_rf["1"]["recall"]
f1_score_good_rf = classification_rep_rf["1"]["f1-score"]
support_good_rf = classification_rep_rf["1"]["support"]

# Extract confusion matrix values
tp_rf = conf_matrix_rf[1, 1]  # True Positives
fp_rf = conf_matrix_rf[0, 1]  # False Positives
fn_rf = conf_matrix_rf[1, 0]  # False Negatives
tn_rf = conf_matrix_rf[0, 0]  # True Negatives

# Print results
print(f"Accuracy: {accuracy_rf:.4f}")

print("\nClassification Report:")
print(f"Class 0 (Bad) - Precision: {precision_bad_rf:.4f}, Recall: {recall_bad_rf:.4f}, F1-Score: {f1_score_bad_rf:.4f}, Support: {support_bad_rf}")
print(f"Class 1 (Good) - Precision: {precision_good_rf:.4f}, Recall: {recall_good_rf:.4f}, F1-Score: {f1_score_good_rf:.4f}, Support: {support_good_rf}")

print("\nConfusion Matrix:")
print(f"TP: {tp_rf}, FP: {fp_rf}, FN: {fn_rf}, TN: {tn_rf}")
# Out:
# Accuracy: 0.8800
#
# Classification Report:
# Class 0 (Bad) - Precision: 0.8993, Recall: 0.8611, F1-Score: 0.8798, Support: 612.0
# Class 1 (Good) - Precision: 0.8616, Recall: 0.8997, F1-Score: 0.8802, Support: 588.0
#
# Confusion Matrix:
# TP: 529, FP: 85, FN: 59, TN: 527

# %% [markdown]
# ### XgBoost Algorithm

# %%
import xgboost as xgb

# Train XGBoost model
xgb_model = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
xgb_model.fit(X_train_scaled, y_train)

# Predict on test data
y_pred_xgb = xgb_model.predict(X_test_scaled)

# Compute evaluation metrics
accuracy_xgb = accuracy_score(y_test, y_pred_xgb)
classification_rep_xgb = classification_report(y_test, y_pred_xgb, output_dict=True)
conf_matrix_xgb = confusion_matrix(y_test, y_pred_xgb)

# Extract precision, recall, f1-score for both classes
precision_bad_xgb = classification_rep_xgb["0"]["precision"]
recall_bad_xgb = classification_rep_xgb["0"]["recall"]
f1_score_bad_xgb = classification_rep_xgb["0"]["f1-score"]
support_bad_xgb = classification_rep_xgb["0"]["support"]

precision_good_xgb = classification_rep_xgb["1"]["precision"]
recall_good_xgb = classification_rep_xgb["1"]["recall"]
f1_score_good_xgb = classification_rep_xgb["1"]["f1-score"]
support_good_xgb = classification_rep_xgb["1"]["support"]

# Extract confusion matrix values
tp_xgb = conf_matrix_xgb[1, 1]  # True Positives
fp_xgb = conf_matrix_xgb[0, 1]  # False Positives
fn_xgb = conf_matrix_xgb[1, 0]  # False Negatives
tn_xgb = conf_matrix_xgb[0, 0]  # True Negatives

# Print results
print(f"Accuracy: {accuracy_xgb:.4f}")

print("\nClassification Report:")
print(f"Class 0 (Bad) - Precision: {precision_bad_xgb:.4f}, Recall: {recall_bad_xgb:.4f}, F1-Score: {f1_score_bad_xgb:.4f}, Support: {support_bad_xgb}")
print(f"Class 1 (Good) - Precision: {precision_good_xgb:.4f}, Recall: {recall_good_xgb:.4f}, F1-Score: {f1_score_good_xgb:.4f}, Support: {support_good_xgb}")

print("\nConfusion Matrix:")
print(f"TP: {tp_xgb}, FP: {fp_xgb}, FN: {fn_xgb}, TN: {tn_xgb}")
# Out:
# Accuracy: 0.8717
#
# Classification Report:
# Class 0 (Bad) - Precision: 0.8829, Recall: 0.8627, F1-Score: 0.8727, Support: 612.0
# Class 1 (Good) - Precision: 0.8605, Recall: 0.8810, F1-Score: 0.8706, Support: 588.0
#
# Confusion Matrix:
# TP: 518, FP: 84, FN: 70, TN: 528
